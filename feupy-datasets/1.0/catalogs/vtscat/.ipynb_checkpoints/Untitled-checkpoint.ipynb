# %% [markdown]
# """
# This script converts `<tev-source_id>.yaml` files to ECSV format table.
#
# VTSCat  is the VERITAS Catalog of gamma-ray observations from this paper:
# https://iopscience.iop.org/article/10.3847/2515-5172/acb147
#
# """

# %%
from feupy.scripts.ipynb_to_gallery import convert_ipynb_to_gallery

# %%
# Import necessary modules
import os
import logging
from astropy.table import Table, Column
import astropy.units as u

from feupy.utils.io import read_yaml
from gammapy.utils.table import table_row_to_dict
from gammapy.utils.scripts import make_path


# Set up logging
logging.basicConfig(level=logging.INFO)
log = logging.getLogger(__name__)

# Dictionary for source categories from VERITAS VTSCat
VTSCAT_DICT = {
    'detect': 'tev-0',
    'non_detect': 'tev-1',
    'crs': 'tev-3',
    'all': 'tev-'
}

# ------------------------------------------------------------------------------
# Paths and directories for data, datasets, and figures
# ------------------------------------------------------------------------------

DATA_PATH = '/home/born-again/Documents/GitHub/feupy-dev/data/vtscat/'
DATA_PATH = make_path(DATA_PATH)

DATA_PATH.mkdir(parents=True, exist_ok=True)

DATASETS_PATH = make_path(f'{DATA_PATH}/datasets/')
DATASETS_PATH.mkdir(parents=True, exist_ok=True)

SOURCES_PATH = make_path(f'{DATA_PATH}/sources/')
SOURCES_PATH.mkdir(parents=True, exist_ok=True)

def read_vtscat_sources(which='all', sources_path=SOURCES_PATH):
    """
    Read VERITAS sources from YAML files based on categories.

    Parameters
    ----------
    which : str, optional
        Key to select source type from `VTSCAT_DICT`, by default 'all'.
    sources_path : str or Path, optional
        Path to the directory containing YAML files, by default `SOURCES_PATH`.

    Returns
    -------
    list of dict
        List of parsed YAML data from selected source files.

    Raises
    ------
    ValueError
        If the source type provided does not exist in the catalog.
    FileNotFoundError
        If no matching files are found.
    """
    data_list = []
    if which not in VTSCAT_DICT:
        raise ValueError(f"Invalid category '{which}'. Valid options are {list(VTSCAT_DICT.keys())}")
    
    prefix = VTSCAT_DICT[which]
    for filename in os.listdir(sources_path):
        if filename.startswith(prefix) and filename.endswith('.yaml'):
            file_path = os.path.join(sources_path, filename)
            data = read_yaml(file_path)
            data_list.append(data)
            log.info(f"Loaded source: {data.get('source_name', filename)} from {filename}")

    if not data_list:
        raise FileNotFoundError(f"No matching files found for key '{which}' in directory '{sources_path}'.")
    
    return data_list

def flatten_data(data):
    """
    Flatten the nested dictionary structure from VTSCat sources.

    Parameters
    ----------
    data : dict
        Dictionary containing the source data.

    Returns
    -------
    dict
        Flattened data dictionary with default values for missing fields.
    """
    return {
        'veritas_id': data.get('source_id', None),
        'common_name': data.get('common_name', 'Unknown'),
        'veritas_name': data.get('veritas_name', {}).get('name', 'Unknown'),
        'veritas_components': data.get('veritas_name', {}).get('components', 'Unknown'),
        'other_names': ', '.join(data.get('other_names', ['Unknown'])),
        'where': data.get('where', 'Unknown'),
        'simbad_id': data.get('pos', {}).get('simbad_id', 'Unknown'),
        'ra': data.get('pos', {}).get('ra', None),
        'dec': data.get('pos', {}).get('dec', None),
        'reference_id': ', '.join(data.get('reference_id', ['Unknown']))
    }

# Read and process the data
data_list = read_vtscat_sources()
flattened_data_list = [flatten_data(data) for data in data_list]

# Define columns for the table based on the flattened data
columns = {
    'veritas_id': Column([d['veritas_id'] for d in flattened_data_list], dtype='int'),
    'common_name': Column([d['common_name'] for d in flattened_data_list], dtype='str', length=20),
    'veritas_name': Column([d['veritas_name'] for d in flattened_data_list], dtype='str', length=20),
    'veritas_components': Column([d['veritas_components'] for d in flattened_data_list], dtype='str', length=20),
    'other_names': Column([d['other_names'] for d in flattened_data_list], dtype='str', length=50),
    'where': Column([d['where'] for d in flattened_data_list], dtype='str', length=10),
    'simbad_id': Column([d['simbad_id'] for d in flattened_data_list], dtype='str', length=20),
    'ra': Column([d['ra'] for d in flattened_data_list], unit=u.deg, dtype='float'),
    'dec': Column([d['dec'] for d in flattened_data_list], unit=u.deg, dtype='float'),
    'reference_id': Column([d['reference_id'] for d in flattened_data_list], dtype='str', length=50)
}

# Create the Astropy Table and set metadata
table = Table(columns)
table.meta['catalog_name'] = 'vtscat'
table.meta['comments'] = ['Reference: https://zenodo.org/records/6163391']

# Set descriptions and formats for columns
table.sort('veritas_id')
table['ra'].description = 'Right Ascension (J2000)'
table['ra'].format = '.3f'
table['dec'].description = 'Declination (J2000)'
table['dec'].format = '.3f'
table['veritas_id'].description = 'Unique identifier of an object (integer)'
table['common_name'].description = 'Common name as frequently used in literature'
table['veritas_name'].description = 'VERITAS name as registered in the AU Registry'
table['other_names'].description = 'Other names used in literature or from catalogs (not a complete list)'
table['where'].description = 'Galactic (gal) or extragalactic (egal) object'
table['reference_id'].description = 'List of references for this catalog'
# Additional columns based on source data
table['source_name'] = [d['veritas_name'] if d['veritas_name'] != 'Unknown' else d['common_name'] for d in table]
table['source_name'].description = 'Source name: "veritas_name" if available, else "common_name"'
# table['source_id'] = [index for index, _ in enumerate(table)]

# Populate the 'type' column based on veritas_id
table['type'] = ['detected' if d['veritas_id'] < 100000 else 
                         'non_detected' if d['veritas_id'] < 300000 else 'crs' 
                         for d in table]
table['type'].description = 'Type of the VERITAS type'
table = table['source_name', 'ra', 'dec', 'type', 'where', 'veritas_name', 'veritas_components', 'common_name', 'other_names', 'veritas_id', 'simbad_id', 'reference_id',]
# Save the table as ECSV format
output_path = f"{SOURCES_PATH}/vtscat.ecsv"
table.write(output_path, format='ascii.ecsv', overwrite=True)
log.info(f"Table saved as ECSV: {output_path}")
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100193.yaml
# INFO:__main__:Loaded source: tev-100193.yaml from tev-100193.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000001.yaml
# INFO:__main__:Loaded source: tev-000001.yaml from tev-000001.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100204.yaml
# INFO:__main__:Loaded source: tev-100204.yaml from tev-100204.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000036.yaml
# INFO:__main__:Loaded source: tev-000036.yaml from tev-000036.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000106.yaml
# INFO:__main__:Loaded source: tev-000106.yaml from tev-000106.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000003.yaml
# INFO:__main__:Loaded source: tev-000003.yaml from tev-000003.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100172.yaml
# INFO:__main__:Loaded source: tev-100172.yaml from tev-100172.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100168.yaml
# INFO:__main__:Loaded source: tev-100168.yaml from tev-100168.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-
yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000034.yaml
# INFO:__main__:Loaded source: tev-000034.yaml from tev-000034.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000166.yaml
# INFO:__main__:Loaded source: tev-000166.yaml from tev-000166.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000007.yaml
# INFO:__main__:Loaded source: tev-000007.yaml from tev-000007.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000119.yaml
# INFO:__main__:Loaded source: tev-000119.yaml from tev-000119.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100200.yaml
# INFO:__main__:Loaded source: tev-100200.yaml from tev-100200.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000091.yaml
# INFO:__main__:Loaded source: tev-000091.yaml from tev-000091.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000168.yaml
# INFO:__main__:Loaded source: tev-000168.yaml from tev-000168.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100174.yaml
# INFO:__main__:Loaded source: tev-100174.yaml from tev-100174.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000154.yaml
# INFO:__main__:Loaded source: tev-000154.yaml from tev-000154.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000136.yaml
# INFO:__main__:Loaded source: tev-000136.yaml from tev-000136.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000014.yaml
# INFO:__main__:Loaded source: tev-000014.yaml from tev-000014.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000011.yaml
# INFO:__main__:Loaded source: tev-000011.yaml from tev-000011.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-100183.yaml
# INFO:__main__:Loaded source: tev-100183.yaml from tev-100183.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/tev-000143.yaml
# INFO:__main__:Loaded source: tev-000143.yaml from tev-000143.yaml
# INFO:__main__:Table saved as ECSV: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/sources/vtscat.ecsv

# %%
output_path = f"{SOURCES_PATH}/vtscat.ecsv"

table = Table.read(output_path, format='ascii.ecsv')
table
# Out:
# <Table length=100>
#  source_name   ...
#                ...
#     str22      ...
# -------------- ...
#  VER J0006+729 ...
#  VER J0025+641 ...
#  VER J0136+390 ...
#  VER J0222+430 ...
#  VER J0232+202 ...
#  VER J0240+612 ...
#            ... ...
#  VER-nodefined ...
# MAXI J1820+070 ...
#       SN2015bn ...
#      SN2017egm ...
#       electron ...
#           iron ...

# %%
cat = SourceCatalogVTSCat()
source = cat[22]

df  = source.reference_id_info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cat = SourceCatalogVTSCat()
#       2 source = cat[22]
#       4 df  = source.reference_id_info()
#
# TypeError: Can't instantiate abstract class SourceCatalogVTSCat with abstract methods description, tag

# %%
# convert_ipynb_to_gallery('Untitled.ipynb', "make_veritas.py")

# %%
# !pyflakes make_veritas.py

# %%
def generate_unique_model_name(reference_id, unique_names):
    """Generate a unique name based on source metadata.
    
    Parameters
    ----------
    table : `~astropy.table.Table`
        Table object containing metadata for the source.
    unique_names : set
        A set of existing unique names to avoid duplicates.

    Returns
    -------
    str
        A unique name for the source file.

    Notes
    -----
    This function creates a unique name by checking the source name and its description or reference ID. 
    If there are duplicates, a letter suffix (e.g., 'a', 'b') is added to ensure uniqueness.
    """
#     meta = table.meta
#     source_id = meta.get('source_id')
#     source = vtscatalog[source_id]  # Assuming vtscatalog is a dictionary or catalog object
#     description = meta.get('description')
#     reference_id = meta.get('reference_id')

    # Generate the base name using the description or reference_id
    base_name = f"Model ({reference_id.strip()[:4]})"

    # Check for uniqueness
    if base_name not in unique_names:
        return base_name

    # Add letter suffixes for duplicates
    for letter in string.ascii_lowercase:  # 'a' to 'z'
        new_name = f"{base_name[:-1]}{letter})"
        if new_name not in unique_names:
            return new_name

    return base_name  # Return the original base name if all else fails

# %%
index = 23

# %%
unique_keys = [] 
for index, _ in enumerate(table):
    reference_id  = [_.strip() for _ in table['reference_id'][index].split(", ")]
    for ref in reference_id:
        yaml_dir = f'{DATASETS_PATH}/{ref}/'
        path = make_path(yaml_dir)
        records = []
        for file in os.listdir(path):
            if file.endswith('info.yaml'):
                try:
                    data = read_yaml(os.path.join(path, file))
                    unique_keys = list(set(unique_keys + list(data.keys())))

                    records.append(data)
                except Exception as e:
                    print(f"Error reading {file}: {e}")
            
            print(data.keys())
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...764...38A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...764...38A/VER-000001.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836...23A/VER-000003.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836...23A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...730L..20A/VER-000003.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...730L..20A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-000007.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100191.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100195.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100192.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100194.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100193.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000034-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000013-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000154-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000138-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000043-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000067-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000069-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000082-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000020-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000138-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000055-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000138-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000022-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000053-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000057-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/info.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...693L.104A/info.yaml
# VER-000001
# VER-000001
# VER-000003
# VER-000003
# VER-000003
# VER-000003
# VER-000007
# VER-000007
# VER-000007
# VER-000007
# VER-000007
# VER-000007
# VER-000007
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# VER-000011
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...693L.104A/VER-000011.yaml
# VER-000011
# VER-000011

# %%
unique_keys_info = ['source_id',
 'reference_id',
 'data_entry',
 'datasets',
 'multiwavelength',
 'datadescription',
 'telescope']
# Out:
# ['source_id',
#  'reference_id',
#  'data_entry',
#  'datasets',
#  'multiwavelength',
#  'datadescription',
#  'telescope']

# %%
unique_keys = [] 

for index, _ in enumerate(table):
    reference_id  = [_.strip() for _ in table['reference_id'][index].split(", ")]
    for ref in reference_id:
        yaml_dir = f'{DATASETS_PATH}/{ref}/'
        path = make_path(yaml_dir)
        for file in os.listdir(path):
            
            if f"VER-{table[index]['veritas_id']:06}" in file and file.endswith('.yaml'):
                try:
                    data = read_yaml(os.path.join(path, file))
                    unique_keys = list(set(unique_keys + list(data.keys())))
                    print(unique_keys)
                    
                    records.append(data)
                except Exception as e:
                    print(f"Error reading {file}: {e}")
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...764...38A/VER-000001.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836...23A/VER-000003.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...730L..20A/VER-000003.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-000007.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000011-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...693L.104A/VER-000011.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000013-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..712K/VER-000014-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..712K/VER-000014-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...779...88A/VER-000014.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738....3A/VER-000014.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...700.1034A/VER-000014-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...700.1034A/VER-000014-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2008ApJ...679.1427A/VER-000014.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...750...94A/VER-000017.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...706L.275A/VER-000018-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000020-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...755..118A/VER-000020.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000022-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-2.yaml
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'flux', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'flux', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'flux', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'flux', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'spec', 'data', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'spec', 'data', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'spec', 'data', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'spec', 'data', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'spec', 'data', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'orbit', 'description', 'flux', 'file_id', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...776...69A/VER-000023.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ICRC...34..792M/VER-000025.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...781L..11A/VER-000025-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...781L..11A/VER-000025-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...760..136A/VER-000025.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...698L.133A/VER-000029.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...888..115A/VER-000030-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...888..115A/VER-000030-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-5.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-4.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-4.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...698L..94A/VER-000030.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...742..127A/VER-000032.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000034-1.yaml
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...715L..49A/VER-000034.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...690L.126A/VER-000036.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009Natur.462..770V/VER-000040.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000043-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...890...97A/VER-000049-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...834....2A/VER-000049-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...834....2A/VER-000049-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-7.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-8.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-5.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-6.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-4.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-7.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-5.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-3.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-6.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-4.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...691L..13D/VER-000049.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...703..169A/VER-000049.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2019ApJ...885..150A/VER-000053-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836..205A/VER-000053-2.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836..205A/VER-000053-1.yaml
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']
# ['source_id', 'pos', 'morph', 'reference_id', 'description', 'flux', 'file_id', 'orbit', 'data', 'spec', 'telescope']
# ['source_id', 'pos', 'morph', 'reference_id', 'telescope', 'description', 'flux', 'file_id', 'orbit', 'spec', 'data']

# %%
unique_keys_yaml = ['source_id',
 'pos',
 'morph',
 'reference_id',
 'telescope',
 'description',
 'flux',
 'file_id',
 'orbit',
 'spec',
 'data']
# Out:
# ['source_id',
#  'pos',
#  'morph',
#  'reference_id',
#  'telescope',
#  'description',
#  'flux',
#  'file_id',
#  'orbit',
#  'spec',
#  'data']

# %%
unique_keys = [] 

for index, _ in enumerate(table):
    reference_id  = [_.strip() for _ in table['reference_id'][index].split(", ")]
    for ref in reference_id:
        yaml_dir = f'{DATASETS_PATH}/{ref}/'
        path = make_path(yaml_dir)
        for file in os.listdir(path):
            
            if f"VER-{table[index]['veritas_id']:06}" in file and file.endswith('.ecsv'):
                if f"sed" in file:
                    
                    try:
                        data = read_yaml(os.path.join(path, file))
#                         unique_keys = list(set(unique_keys + list(data.keys())))
#                         print(data['e_ref'])

                        records.append(data)
                    except Exception as e:
                        print(f"Error reading {file}: {e}")
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...764...38A/VER-000001-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836...23A/VER-000003-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...730L..20A/VER-000003-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-000007-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...726...43A/VER-000011-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...693L.104A/VER-000011-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...782...13A/VER-000013-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...817L...7A/VER-000014-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...779...88A/VER-000014-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...700.1034A/VER-000014-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2008ApJ...679.1427A/VER-000014-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...750...94A/VER-000017-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...706L.275A/VER-000018-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...706L.275A/VER-000018-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...755..118A/VER-000020-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-2-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-1-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...932..129A/VER-000023-3-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...776...69A/VER-000023-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-8.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-9.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-10.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-7.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022A&A...658A..83A/VER-000025-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017APh....91...34A/VER-000025-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ICRC...34..792M/VER-000025-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...781L..11A/VER-000025-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...781L..11A/VER-000025-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...698L.133A/VER-000029-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55600-55603-sed-107.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55614-55623-sed-108.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-8.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-7.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55569-55573-sed-105.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57756-57783-sed-129.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57363-57373-sed-126.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55544-55565-sed-104.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58464-58467-sed-137.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56707-56718-sed-121.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55916-55921-sed-112.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD54856-54862-sed-100.ecsv
# Error reading VER-000001-sed.ecsv: string indices must be integers
# Error reading VER-000003-sed.ecsv: string indices must be integers
# Error reading VER-000003-sed.ecsv: string indices must be integers
# Error reading VER-000007-sed-1.ecsv: string indices must be integers
# Error reading VER-000011-sed-2.ecsv: string indices must be integers
# Error reading VER-000011-sed-1.ecsv: string indices must be integers
# Error reading VER-000011-sed.ecsv: string indices must be integers
# Error reading VER-000013-sed-2.ecsv: string indices must be integers
# Error reading VER-000013-sed-3.ecsv: string indices must be integers
# Error reading VER-000013-sed-1.ecsv: string indices must be integers
# Error reading VER-000014-sed-2.ecsv: string indices must be integers
# Error reading VER-000014-sed-1.ecsv: string indices must be integers
# Error reading VER-000014-sed-3.ecsv: string indices must be integers
# Error reading VER-000014-sed.ecsv: string indices must be integers
# Error reading VER-000014-sed.ecsv: string indices must be integers
# Error reading VER-000014-sed.ecsv: string indices must be integers
# Error reading VER-000017-sed.ecsv: string indices must be integers
# Error reading VER-000018-sed-2.ecsv: string indices must be integers
# Error reading VER-000018-sed-1.ecsv: string indices must be integers
# Error reading VER-000020-sed.ecsv: string indices must be integers
# Error reading VER-000023-2-sed.ecsv: string indices must be integers
# Error reading VER-000023-1-sed.ecsv: string indices must be integers
# Error reading VER-000023-3-sed.ecsv: string indices must be integers
# Error reading VER-000023-sed.ecsv: string indices must be integers
# Error reading VER-000025-sed-6.ecsv: string indices must be integers
# Error reading VER-000025-sed-2.ecsv: string indices must be integers
# Error reading VER-000025-sed-1.ecsv: string indices must be integers
# Error reading VER-000025-sed-8.ecsv: string indices must be integers
# Error reading VER-000025-sed-3.ecsv: string indices must be integers
# Error reading VER-000025-sed-5.ecsv: string indices must be integers
# Error reading VER-000025-sed-9.ecsv: string indices must be integers
# Error reading VER-000025-sed-10.ecsv: string indices must be integers
# Error reading VER-000025-sed-7.ecsv: string indices must be integers
# Error reading VER-000025-sed-4.ecsv: string indices must be integers
# Error reading VER-000025-sed-2.ecsv: string indices must be integers
# Error reading VER-000025-sed-1.ecsv: string indices must be integers
# Error reading VER-000025-sed-3.ecsv: string indices must be integers
# Error reading VER-000025-sed.ecsv: string indices must be integers
# Error reading VER-000025-sed-2.ecsv: string indices must be integers
# Error reading VER-000025-sed-1.ecsv: string indices must be integers
# Error reading VER-000029-sed.ecsv: string indices must be integers
# Error reading VER-000030-MJD55600-55603-sed-107.ecsv: string indices must be integers
# Error reading VER-000030-MJD55614-55623-sed-108.ecsv: string indices must be integers
# Error reading VER-000030-sed-8.ecsv: string indices must be integers
# Error reading VER-000030-sed-7.ecsv: string indices must be integers
# Error reading VER-000030-MJD55569-55573-sed-105.ecsv: string indices must be integers
# Error reading VER-000030-MJD57756-57783-sed-129.ecsv: string indices must be integers
# Error reading VER-000030-MJD57363-57373-sed-126.ecsv: string indices must be integers
# Error reading VER-000030-MJD55544-55565-sed-104.ecsv: string indices must be integers
# Error reading VER-000030-MJD58464-58467-sed-137.ecsv: string indices must be integers
# Error reading VER-000030-MJD56707-56718-sed-121.ecsv: string indices must be integers
# Error reading VER-000030-MJD55916-55921-sed-112.ecsv: string indices must be integers
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56680-56687-sed-120.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56958-56966-sed-123.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-14.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57417-57432-sed-128.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-10.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55643-55657-sed-110.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58101-58104-sed-132.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58073-58084-sed-131.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58153-58155-sed-135.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57801-57815-sed-130.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58143-58144-sed-134.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56970-56989-sed-124.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55259-55277-sed-103.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57030-57041-sed-125.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55951-55956-sed-115.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-12.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55235-55248-sed-102.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55940-55950-sed-114.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55585-55600-sed-106.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55122-55135-sed-101.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55888-55902-sed-111.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-9.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56652-56664-sed-119.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55921-55928-sed-113.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-11.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58455-58463-sed-136.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56330-56342-sed-118.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56243-56256-sed-116.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD55624-55631-sed-109.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD58142-58143-sed-133.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56265-56283-sed-117.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD56730-56747-sed-122.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923..241A/VER-000030-MJD57389-57401-sed-127.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923...17T/VER-000030-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923...17T/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923...17T/VER-000030-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923...17T/VER-000030-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...923...17T/VER-000030-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...888..115A/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...888..115A/VER-000030-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017AIPC.1792d0023S/VER-000030-sed-2.ecsv
# Error reading VER-000030-MJD54856-54862-sed-100.ecsv: string indices must be integers
# Error reading VER-000030-MJD56680-56687-sed-120.ecsv: string indices must be integers
# Error reading VER-000030-sed-4.ecsv: string indices must be integers
# Error reading VER-000030-MJD56958-56966-sed-123.ecsv: string indices must be integers
# Error reading VER-000030-sed-14.ecsv: string indices must be integers
# Error reading VER-000030-MJD57417-57432-sed-128.ecsv: string indices must be integers
# Error reading VER-000030-sed-10.ecsv: string indices must be integers
# Error reading VER-000030-MJD55643-55657-sed-110.ecsv: string indices must be integers
# Error reading VER-000030-MJD58101-58104-sed-132.ecsv: string indices must be integers
# Error reading VER-000030-sed-6.ecsv: string indices must be integers
# Error reading VER-000030-MJD58073-58084-sed-131.ecsv: string indices must be integers
# Error reading VER-000030-MJD58153-58155-sed-135.ecsv: string indices must be integers
# Error reading VER-000030-MJD57801-57815-sed-130.ecsv: string indices must be integers
# Error reading VER-000030-MJD58143-58144-sed-134.ecsv: string indices must be integers
# Error reading VER-000030-MJD56970-56989-sed-124.ecsv: string indices must be integers
# Error reading VER-000030-MJD55259-55277-sed-103.ecsv: string indices must be integers
# Error reading VER-000030-MJD57030-57041-sed-125.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-3.ecsv: string indices must be integers
# Error reading VER-000030-MJD55951-55956-sed-115.ecsv: string indices must be integers
# Error reading VER-000030-sed-12.ecsv: string indices must be integers
# Error reading VER-000030-MJD55235-55248-sed-102.ecsv: string indices must be integers
# Error reading VER-000030-MJD55940-55950-sed-114.ecsv: string indices must be integers
# Error reading VER-000030-MJD55585-55600-sed-106.ecsv: string indices must be integers
# Error reading VER-000030-MJD55122-55135-sed-101.ecsv: string indices must be integers
# Error reading VER-000030-MJD55888-55902-sed-111.ecsv: string indices must be integers
# Error reading VER-000030-sed-9.ecsv: string indices must be integers
# Error reading VER-000030-MJD56652-56664-sed-119.ecsv: string indices must be integers
# Error reading VER-000030-MJD55921-55928-sed-113.ecsv: string indices must be integers
# Error reading VER-000030-sed-11.ecsv: string indices must be integers
# Error reading VER-000030-MJD58455-58463-sed-136.ecsv: string indices must be integers
# Error reading VER-000030-sed-5.ecsv: string indices must be integers
# Error reading VER-000030-MJD56330-56342-sed-118.ecsv: string indices must be integers
# Error reading VER-000030-MJD56243-56256-sed-116.ecsv: string indices must be integers
# Error reading VER-000030-MJD55624-55631-sed-109.ecsv: string indices must be integers
# Error reading VER-000030-MJD58142-58143-sed-133.ecsv: string indices must be integers
# Error reading VER-000030-MJD56265-56283-sed-117.ecsv: string indices must be integers
# Error reading VER-000030-MJD56730-56747-sed-122.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# Error reading VER-000030-MJD57389-57401-sed-127.ecsv: string indices must be integers
# Error reading VER-000030-sed-4.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-3.ecsv: string indices must be integers
# Error reading VER-000030-sed-5.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-3.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ICRC...35..729M/VER-000030-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...780..168A/VER-000030-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...742..127A/VER-000032-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...715L..49A/VER-000034-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...690L.126A/VER-000036-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009Natur.462..770V/VER-000040-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...834....2A/VER-000049-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...834....2A/VER-000049-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...819..156B/VER-000049-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-9.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-8.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-7.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...578A..22A/VER-000049-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-7.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738...25A/VER-000049-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...691L..13D/VER-000049-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...703..169A/VER-000049-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-9.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-8.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-7.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-11.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-10.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...891..170V/VER-000053-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJ...836..205A/VER-000053-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...779...92A/VER-000053-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...707..612A/VER-000054-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2008ApJ...684L..73A/VER-000054-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...788..158A/VER-000055-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...709L.163A/VER-000055-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...695.1370A/VER-000055-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...911L..11E/VER-000058-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...746..141A/VER-000058-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...746..141A/VER-000058-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...746..141A/VER-000058-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...716..819A/VER-000058-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...716..819A/VER-000058-sed-3.ecsv
# Error reading VER-000030-sed-4.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-5.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# Error reading VER-000030-sed-4.ecsv: string indices must be integers
# Error reading VER-000030-sed-1.ecsv: string indices must be integers
# Error reading VER-000030-sed-3.ecsv: string indices must be integers
# Error reading VER-000030-sed-2.ecsv: string indices must be integers
# Error reading VER-000032-sed.ecsv: string indices must be integers
# Error reading VER-000034-sed.ecsv: string indices must be integers
# Error reading VER-000036-sed.ecsv: string indices must be integers
# Error reading VER-000040-sed.ecsv: string indices must be integers
# Error reading VER-000049-sed-1.ecsv: string indices must be integers
# Error reading VER-000049-sed-2.ecsv: string indices must be integers
# Error reading VER-000049-sed-1.ecsv: string indices must be integers
# Error reading VER-000049-sed-2.ecsv: string indices must be integers
# Error reading VER-000049-sed-3.ecsv: string indices must be integers
# Error reading VER-000049-sed-1.ecsv: string indices must be integers
# Error reading VER-000049-sed-6.ecsv: string indices must be integers
# Error reading VER-000049-sed-9.ecsv: string indices must be integers
# Error reading VER-000049-sed-8.ecsv: string indices must be integers
# Error reading VER-000049-sed-4.ecsv: string indices must be integers
# Error reading VER-000049-sed-2.ecsv: string indices must be integers
# Error reading VER-000049-sed-3.ecsv: string indices must be integers
# Error reading VER-000049-sed-7.ecsv: string indices must be integers
# Error reading VER-000049-sed-5.ecsv: string indices must be integers
# Error reading VER-000049-sed-1.ecsv: string indices must be integers
# Error reading VER-000049-sed-6.ecsv: string indices must be integers
# Error reading VER-000049-sed-4.ecsv: string indices must be integers
# Error reading VER-000049-sed-2.ecsv: string indices must be integers
# Error reading VER-000049-sed-3.ecsv: string indices must be integers
# Error reading VER-000049-sed-7.ecsv: string indices must be integers
# Error reading VER-000049-sed-5.ecsv: string indices must be integers
# Error reading VER-000049-sed.ecsv: string indices must be integers
# Error reading VER-000049-sed.ecsv: string indices must be integers
# Error reading VER-000053-sed-9.ecsv: string indices must be integers
# Error reading VER-000053-sed-8.ecsv: string indices must be integers
# Error reading VER-000053-sed-3.ecsv: string indices must be integers
# Error reading VER-000053-sed-5.ecsv: string indices must be integers
# Error reading VER-000053-sed-6.ecsv: string indices must be integers
# Error reading VER-000053-sed-7.ecsv: string indices must be integers
# Error reading VER-000053-sed-11.ecsv: string indices must be integers
# Error reading VER-000053-sed-4.ecsv: string indices must be integers
# Error reading VER-000053-sed-1.ecsv: string indices must be integers
# Error reading VER-000053-sed-10.ecsv: string indices must be integers
# Error reading VER-000053-sed-2.ecsv: string indices must be integers
# Error reading VER-000053-sed.ecsv: string indices must be integers
# Error reading VER-000053-sed.ecsv: string indices must be integers
# Error reading VER-000054-sed.ecsv: string indices must be integers
# Error reading VER-000054-sed.ecsv: string indices must be integers
# Error reading VER-000055-sed-1.ecsv: string indices must be integers
# Error reading VER-000055-sed-1.ecsv: string indices must be integers
# Error reading VER-000055-sed.ecsv: string indices must be integers
# Error reading VER-000058-sed-1.ecsv: string indices must be integers
# Error reading VER-000058-sed-2.ecsv: string indices must be integers
# Error reading VER-000058-sed-3.ecsv: string indices must be integers
# Error reading VER-000058-sed-1.ecsv: string indices must be integers
# Error reading VER-000058-sed-2.ecsv: string indices must be integers
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...716..819A/VER-000058-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2008ApJ...679..397A/VER-000058-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...785L..16A/VER-000067-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...785L..16A/VER-000067-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...785L..16A/VER-000067-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...708L.100A/VER-000067-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016MNRAS.461..202A/VER-000071-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ApJ...799....7A/VER-000082-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-14.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-11.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-15.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-9.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-8.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018A&A...620A.181A/VER-000091-sed-6.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017A&A...603A..31A/VER-000091-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017A&A...603A..31A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016A&A...594A..76A/VER-000091-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016A&A...594A..76A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...573A..50A/VER-000091-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015A&A...573A..50A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ApJ...812...65F/VER-000091-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ApJ...812...65F/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...729....2A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...727..129A/VER-000091-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...727..129A/VER-000091-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ApJ...808..110A/VER-000101-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016MNRAS.459.2550A/VER-000105-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...913..115A/VER-000106-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...821..129A/VER-000106-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...790..149A/VER-000106-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...913..115A/VER-000110-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...821..129A/VER-000110-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020APh...11702403A/VER-000118-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020APh...11702403A/VER-000119-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020APh...11702403A/VER-000119-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...787..166A/VER-000132-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...866...24A/VER-000136-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...719L..69A/VER-000136-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...862...41A/VER-000137-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...775....3A/VER-000138-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000141-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...788...78A/VER-000141-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000143-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...788...78A/VER-000143-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000144-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...770...93A/VER-000144-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000146-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...867L..19A/VER-000146-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2014ApJ...783...16A/VER-000146-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...856...95A/VER-000148-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...762...92A/VER-000148-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2009ApJ...703L...6A/VER-000149-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...894...51A/VER-000153-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...714..163A/VER-000153-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017MNRAS.471.2117A/VER-000154-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738..169A/VER-000154-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011ApJ...738..169A/VER-000154-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...913..115A/VER-000165-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2011Sci...334...69V/VER-000166-sed.ecsv
# Error reading VER-000058-sed-3.ecsv: string indices must be integers
# Error reading VER-000058-sed-1.ecsv: string indices must be integers
# Error reading VER-000058-sed.ecsv: string indices must be integers
# Error reading VER-000067-sed-3.ecsv: string indices must be integers
# Error reading VER-000067-sed-1.ecsv: string indices must be integers
# Error reading VER-000067-sed-2.ecsv: string indices must be integers
# Error reading VER-000067-sed.ecsv: string indices must be integers
# Error reading VER-000071-sed.ecsv: string indices must be integers
# Error reading VER-000082-sed-1.ecsv: string indices must be integers
# Error reading VER-000091-sed-3.ecsv: string indices must be integers
# Error reading VER-000091-sed-4.ecsv: string indices must be integers
# Error reading VER-000091-sed-14.ecsv: string indices must be integers
# Error reading VER-000091-sed-5.ecsv: string indices must be integers
# Error reading VER-000091-sed-11.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-15.ecsv: string indices must be integers
# Error reading VER-000091-sed-9.ecsv: string indices must be integers
# Error reading VER-000091-sed-8.ecsv: string indices must be integers
# Error reading VER-000091-sed-6.ecsv: string indices must be integers
# Error reading VER-000091-sed-1.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-1.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-3.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-1.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000091-sed-1.ecsv: string indices must be integers
# Error reading VER-000091-sed-2.ecsv: string indices must be integers
# Error reading VER-000101-sed.ecsv: string indices must be integers
# Error reading VER-000105-sed.ecsv: string indices must be integers
# Error reading VER-000106-sed.ecsv: string indices must be integers
# Error reading VER-000106-sed.ecsv: string indices must be integers
# Error reading VER-000106-sed.ecsv: string indices must be integers
# Error reading VER-000110-sed.ecsv: string indices must be integers
# Error reading VER-000110-sed.ecsv: string indices must be integers
# Error reading VER-000118-sed-1.ecsv: string indices must be integers
# Error reading VER-000119-sed-3.ecsv: string indices must be integers
# Error reading VER-000119-sed-2.ecsv: string indices must be integers
# Error reading VER-000132-sed.ecsv: string indices must be integers
# Error reading VER-000136-sed-1.ecsv: string indices must be integers
# Error reading VER-000136-sed.ecsv: string indices must be integers
# Error reading VER-000137-sed-1.ecsv: string indices must be integers
# Error reading VER-000138-sed.ecsv: string indices must be integers
# Error reading VER-000141-sed.ecsv: string indices must be integers
# Error reading VER-000141-sed.ecsv: string indices must be integers
# Error reading VER-000143-sed.ecsv: string indices must be integers
# Error reading VER-000143-sed.ecsv: string indices must be integers
# Error reading VER-000144-sed.ecsv: string indices must be integers
# Error reading VER-000144-sed.ecsv: string indices must be integers
# Error reading VER-000146-sed.ecsv: string indices must be integers
# Error reading VER-000146-sed-1.ecsv: string indices must be integers
# Error reading VER-000146-sed.ecsv: string indices must be integers
# Error reading VER-000148-sed-1.ecsv: string indices must be integers
# Error reading VER-000148-sed.ecsv: string indices must be integers
# Error reading VER-000149-sed.ecsv: string indices must be integers
# Error reading VER-000153-sed-1.ecsv: string indices must be integers
# Error reading VER-000153-sed.ecsv: string indices must be integers
# Error reading VER-000154-sed-3.ecsv: string indices must be integers
# Error reading VER-000154-sed-2.ecsv: string indices must be integers
# Error reading VER-000154-sed-3.ecsv: string indices must be integers
# Error reading VER-000165-sed.ecsv: string indices must be integers
# Error reading VER-000166-sed.ecsv: string indices must be integers
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015ApJ...815L..22A/VER-000167-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018Sci...361.1378I/VER-000168-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861L..20A/VER-000168-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861L..20A/VER-000168-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000170-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...861..134A/VER-000171-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...866...24A/VER-000172-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2020ApJ...896...41A/VER-000173-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...867L..19A/VER-000174-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...867L..19A/VER-000174-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018ApJ...867L..19A/VER-000174-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2021ApJ...913..115A/VER-000175-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017ApJS..233....7A/VER-000176-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-000177-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-000178-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2023ApJ...950..152A/VER-000179-1-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2013ApJ...779..150A/VER-100171-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...720.1174A/VER-100174-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...720.1174A/VER-100175-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...720.1174A/VER-100176-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2010ApJ...720.1174A/VER-100177-sed.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2015MNRAS.446.2456D/VER-100181-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...754...77A/VER-100183-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100191-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100192-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100193-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100194-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2012ApJ...759..102A/VER-100195-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100199-sed-5.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100199-sed-4.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100199-sed-3.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100199-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100199-sed-2.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100200-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022ApJ...924...95A/VER-100201-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2017A&A...607A.115I/VER-100202-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2022MNRAS.517.4736A/VER-100203-sed-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018PhRvD..98f2004A/VER-300000-sedCR-1.ecsv
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2018PhRvD..98b2009A/VER-300026-sedCR-1.ecsv
# Error reading VER-000167-sed.ecsv: string indices must be integers
# Error reading VER-000168-sed-1.ecsv: string indices must be integers
# Error reading VER-000168-sed-2.ecsv: string indices must be integers
# Error reading VER-000168-sed-1.ecsv: string indices must be integers
# Error reading VER-000170-sed.ecsv: string indices must be integers
# Error reading VER-000171-sed.ecsv: string indices must be integers
# Error reading VER-000172-sed-1.ecsv: string indices must be integers
# Error reading VER-000173-sed-2.ecsv: string indices must be integers
# Error reading VER-000174-sed-3.ecsv: string indices must be integers
# Error reading VER-000174-sed-4.ecsv: string indices must be integers
# Error reading VER-000174-sed-5.ecsv: string indices must be integers
# Error reading VER-000175-sed.ecsv: string indices must be integers
# Error reading VER-000176-sed-1.ecsv: string indices must be integers
# Error reading VER-000177-sed-1.ecsv: string indices must be integers
# Error reading VER-000178-sed-1.ecsv: string indices must be integers
# Error reading VER-000179-1-sed.ecsv: string indices must be integers
# Error reading VER-100171-sed.ecsv: string indices must be integers
# Error reading VER-100174-sed.ecsv: string indices must be integers
# Error reading VER-100175-sed.ecsv: string indices must be integers
# Error reading VER-100176-sed.ecsv: string indices must be integers
# Error reading VER-100177-sed.ecsv: string indices must be integers
# Error reading VER-100181-sed-1.ecsv: string indices must be integers
# Error reading VER-100183-sed-1.ecsv: string indices must be integers
# Error reading VER-100191-sed-1.ecsv: string indices must be integers
# Error reading VER-100192-sed-1.ecsv: string indices must be integers
# Error reading VER-100193-sed-1.ecsv: string indices must be integers
# Error reading VER-100194-sed-1.ecsv: string indices must be integers
# Error reading VER-100195-sed-1.ecsv: string indices must be integers
# Error reading VER-100199-sed-5.ecsv: string indices must be integers
# Error reading VER-100199-sed-4.ecsv: string indices must be integers
# Error reading VER-100199-sed-3.ecsv: string indices must be integers
# Error reading VER-100199-sed-1.ecsv: string indices must be integers
# Error reading VER-100199-sed-2.ecsv: string indices must be integers
# Error reading VER-100200-sed-1.ecsv: string indices must be integers
# Error reading VER-100201-sed-1.ecsv: string indices must be integers
# Error reading VER-100202-sed-1.ecsv: string indices must be integers
# Error reading VER-100203-sed-1.ecsv: string indices must be integers
# Error reading VER-300000-sedCR-1.ecsv: string indices must be integers
# Error reading VER-300026-sedCR-1.ecsv: string indices must be integers

# %%
records = []
for file in os.listdir(path):
    if file.endswith('info.yaml'):
        try:
            data = read_yaml(os.path.join(path, file))
            records.append(data)
        except Exception as e:
            print(f"Error reading {file}: {e}")

# return records
# Out:
# INFO:feupy.utils.io:Successfully loaded YAML file: /home/born-again/Documents/GitHub/feupy-dev/data/vtscat/datasets/2016ApJ...821..129A/info.yaml

# %%
records
# Out:
# [{'reference_id': '2016ApJ...821..129A',
#   'source_id': [106, 110, 165],
#   'telescope': ['veritas'],
#   'datasets': ['VER-000106.yaml',
#    'VER-000106-sed.ecsv',
#    'VER-000110.yaml',
#    'VER-000110-sed.ecsv',
#    'VER-000165.yaml'],
#   'data_entry': {'status': 'complete',
#    'reviewed': True,
#    'notes': 'multiple spectral models for GC (ID 106) given in paper; added them in comments in yaml file'}}]

# %%
unique_names = []
_DICT_MODELS = {}

[generate_unique_model_name(_, unique_names ) for _ in _ids]
# Out:
# ['Model (2021)', 'Model (2016)']

# %%
_DICT_MODELS = {}

_list = [(int(_.strip()[:4]), _.strip()) for index, _ in enumerate(_ids)]
for index, item in enumerate(_list):
    _DICT_MODELS = dict(
    f'Model_{index}' = )
# Out:
# [(2017, '2017ApJ...836...23A'), (2011, '2011ApJ...730L..20A')]

# %%
import pandas as pd
df.reference_id[1]
# Out:
# '2017ApJ...836...23A, 2011ApJ...730L..20A'
